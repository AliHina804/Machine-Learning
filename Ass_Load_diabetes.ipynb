# %% [markdown]
# <a href="https://colab.research.google.com/github/AliHina804/Machine-Learning/blob/main/Ass_Load_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
dataset = load_diabetes()

# %%
dataset.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
dataset.feature_names
dataset.target_filename
# Out:
# 'diabetes_target.csv.gz'

# %%
data_frame = pd.DataFrame(dataset.data, columns=dataset.feature_names)
data_frame['s1']
# s = dataset.feature_names[4].values  // error
# print(s)
# Out:
# 0     -0.044223
# 1     -0.008449
# 2     -0.045599
# 3      0.012191
# 4      0.003935
#          ...
# 437   -0.005697
# 438    0.049341
# 439   -0.037344
# 440    0.016318
# 441    0.083740
# Name: s1, Length: 442, dtype: float64

# %%
data_frame['target'] = dataset.target
data_frame.head()
# data_frame.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
plt.scatter(data_frame['s1'], data_frame['target'])

# %%
dataset.data.shape
# Out:
# (442, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target)

# %%
Scalar = StandardScaler()
X_train = Scalar.fit_transform(X_train)
X_test = Scalar.transform(X_test)

# %%
X_train_df = pd.DataFrame(X_train, columns=dataset.feature_names) #coz isnull() is a pandas' function
# X_train_df.head()
null = X_train_df.isnull().sum()
print(null)
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
msc = mean_squared_error(y_test, y_pred)
print(msc)
# Out:
# 3568.595979934987

# %%
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.40894854657870905

# %%
john_data = np.array([[0.05, -0.02, 0.03, 0.04, -0.03, 0.02, -0.01, 0.03, 0.05, 0.01]])


john_prediction = model.predict(john_data)
print(john_prediction)
# Out:
# [154.42432593]
